# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
import requests
response=[]
for i in range(1,22):
    url = "https://stores.vishalmegamart.com/?page="+str(i)

    payload  = {}
    headers = {
      'Cookie': 'XSRF-TOKEN=%3D; vishal_mega_mart_session=%3D'
    }

    res=requests.request("GET", url, headers=headers, data = payload)
    response.append(res.text.encode('utf8'))
    print(res.text.encode('utf8'))
# Out:
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="Auw5w7x1GH9ESizJQAXwK4sEmpv3Vqid8aL81GBe" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...
# ...
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...

# %%
response[20]
# Out:
# b'<!doctype html><html lang="en" itemscope itemtype="http://www.schema.org/WebPage"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="theme-color" content="#00626e"><meta name="mobile-web-app-capable" content="yes"><title>Grocery, Clothing and Household Items | Vishal Mega Mart</title><meta itemprop="name" content="Grocery, Clothing and Household Items | Vishal Mega Mart" /><meta name="robots" content="index, follow"><meta name="googlebot" content="index, follow"><meta name="description" itemprop="description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"/><meta name="keywords" content="Grocery, Clothing and Household Items | Vishal Mega Mart"/><meta property="og:title" content="Grocery, Clothing and Household Items | Vishal Mega Mart"><meta property="og:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="twitter:description" content="Vishal Mega Mart is India\xe2\x80\x99s leading Fashion led hypermarket stores. Locate our nearest Shopping Mart and buy daily grocery, household items and Apparels"><meta name="copyright" content="\xc2\xa9 Copyright 2010-20 Vishal Mega Mart"/><link rel="canonical" href="https://stores.vishalmegamart.com"><link rel="icon" type="image/png" sizes="32x32" href="https://stores.vishalmegamart.com/vishalmms/images/favicon/favicon-32x32.png"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/bootstrap.min.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/flaticons/flaticon.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/font/icon_fonts/css/all_icons.css?ver=9"><link rel="preload stylesheet" as="style" href="https://stores.vishalmegamart.com/vishalmms/css/common/common.css?ver=9"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/store-locator/store-locator.css?ver=9" rel="stylesheet" type="text/css"><link async defer href="https://stores.vishalmegamart.com/vishalmms/css/search/search-no-result.css?ver=9" rel="stylesheet" type="text/css"></head><body><div class="d-none"><input type="hidden" id="host" value="https://stores.vishalmegamart.com" /><input type="hidden" id="csrf_token" value="gildmRojICEz1KEjjYch29hlTki2TKIQbGzvwenq" /><input type="hidden" id="radiusUrl" value="https://stores.vishalmegamart.com/radius" /><input type="hidden" id="localityUrl" value="https://stores.vishalmegamart.com/city" /><input type="hidden" id="cityUrl" value="https://stores.vishalmegamart.com/state" /><input type="hidden" id="routeinfo" value="index" /><input type="hidden" id="MapMarkerPath" value="https://stores.vishalmegamart.com/vishalmms/images/map-icon.png" /><input type="hidden" id="markerClustererPath" value="https://stores.vishalmegamart.com/vishalmms/images/m" /><input type="hidden" name="recaptcha" id="recaptcha1" class="recaptcha"><input type="hidden" id="recapcha-key" value="6LdaGrIZAAAAAGYsW1giaHy0TZx5UBFUpiRmuPaS" /></div><div class="container-fluid p-0"><header><div class="container px-sm-0"><div class="row"><div class="col-md-3 col-sm-5 col-5 logo-blk"><a href="https://stores.vishalmegamart.com"><img src="https://stores.vishalmegamart.com/vishalmms/images/logo.svg" width="155" height="34" alt="logo"></a></div><div class="col-md-9 col-sm-7 col-7 menu-links d-flex align-items-center"><ul class="right-header-content"><li><a href="https://www.vishalmegamart.com/en-in/orders?utm_source=Vishal-Mega-Mart&amp;utm_medium=store_locator&amp;utm_content=header" target="_blank"><img src="https://stores.vishalmegamart.com/vishalmms/images/icon-order-list-white.svg" width="18" height="20" alt=""><span>My Past Orders</spa ...

# %%
z=BeautifulSoup(response[20], 'html.parser')

# %%
# Store Name
z.find_all('div',class_='card h-100 info-card idx-str-info-card rounded-0')[0].find('a',class_='col-store-name txt-color-3 txt-hover-1').text
# Out:
# ' Vishal Mega Mart '

# %%
# City Name
z.find_all('div',class_='card h-100 info-card idx-str-info-card rounded-0')[0].find('span',class_='mb-0 idx-str-locality').text.replace('\xa0','')
# Out:
# 'Bengaluru'

# %%
# Full Address
z.find_all('div',class_='card h-100 info-card idx-str-info-card rounded-0')[0].find('span',class_='store-address-info idx-info-card-str-add-info').text
# Out:
# ' Uttarahalli-Kengeri Main Road, Srinivaspura ,Ganakallu Village, Bengaluru South, Bengaluru, Karnataka 560060'

# %%
# Phone Number
z.find_all('div',class_='card h-100 info-card idx-str-info-card rounded-0')[0].find('a',class_='txt-hover-1 txt-color-1').text
# Out:
# '0734 9536 444 '

# %%
# Timing
z.find_all('div',class_='card h-100 info-card idx-str-info-card rounded-0')[0].find('span',class_='store-time-info idx-info-card-str-time-info').text
# Out:
# '10:00 AM to 09:00 PM'

# %%
# Coordinates
z.find_all('div',class_='col-md-6 col-sm-6 col-6 form-group mb-0 pl-2')[0].find('a')['href'].split('=')[-1]
# Out:
# '12.9037588,77.5078448'

# %% [markdown]
# # Now will scrap out the data from all 559 stores.

# %%
store_name_lst=[]
city_name_lst=[]
full_address_lst=[]
phone_lst=[]
timing_lst=[]
coordinate_lst=[]
for i in range(len(response)):
    z=BeautifulSoup(response[i], 'html.parser')
    for j in range(len(z.find_all('div',class_='card h-100 info-card idx-str-info-card rounded-0'))):
        
        store_name_lst.append(z.find_all('div',class_='card h-100 info-card idx-str-info-card rounded-0')[j].find('a',class_='col-store-name txt-color-3 txt-hover-1').text)
        
        city_name_lst.append(z.find_all('div',class_='card h-100 info-card idx-str-info-card rounded-0')[j].find('span',class_='mb-0 idx-str-locality').text.replace('\xa0',''))
        
        full_address_lst.append(z.find_all('div',class_='card h-100 info-card idx-str-info-card rounded-0')[j].find('span',class_='store-address-info idx-info-card-str-add-info').text)
        
        phone_lst.append(z.find_all('div',class_='card h-100 info-card idx-str-info-card rounded-0')[j].find('a',class_='txt-hover-1 txt-color-1').text)
        
        timing_lst.append(z.find_all('div',class_='card h-100 info-card idx-str-info-card rounded-0')[j].find('span',class_='store-time-info idx-info-card-str-time-info').text)
        
        coordinate_lst.append(z.find_all('div',class_='col-md-6 col-sm-6 col-6 form-group mb-0 pl-2')[j].find('a')['href'].split('=')[-1])

# %%
len(coordinate_lst)
# Out:
# 559

# %%
coordinate_lst
# Out:
# ['28.648012,77.190996',
#  '28.5346856,77.2185205',
#  '28.6424381,77.1231081',
#  '28.6666937,77.286952',
#  '28.5341443,77.2598518',
#  '28.6200336,77.3141057',
#  '28.5464968,77.1248465',
#  '28.6892564,77.2873552',
#  '28.5930974,77.0948611',
#  '28.636198,77.0940125',
#  '28.5124855,77.2325939',
#  '28.510246,77.201534',
#  '28.7029413,77.1331552',
#  '28.5988792,77.0817318',
#  '28.644719,77.3328012',
#  '28.5009246,77.1857872',
#  '28.60444,77.06863',
#  '28.5848575,77.0716569',
#  '28.6348941,77.0691294',
#  '28.7246615,77.2761025',
#  '28.6107789,77.3542369',
#  '28.5023145,77.2840019',
#  '28.6687973,77.0747393',
#  '28.7439774,77.197884',
#  '28.6925633,77.0890028',
#  '27.4768092,94.5587582',
#  '24.8277607,93.9448529',
#  '24.7697528,93.9367848',
#  '13.3554173,74.7511777',
#  '26.995227,94.6444206',
#  '13.2079409,79.0989907',
#  '13.1290206,78.11923',
#  '13.106267,77.5775387',
#  '13.0903735,77.5397586',
#  '13.0752313,77.5576656',
#  '13.0643185,77.6483373',
#  '13.0607617,77.5818538',
#  '13.05451,77.50773825',
#  '24.4988558,94.0123231',
#  '13.0331722,77.5037175',
#  '13.0295949,77.5611243',
#  '13.0208334,77.6856607',
#  '13.0023837,77.5261084',
#  '13.0042425,77.7116173',
#  '13.0269472,76.1054202',
#  '12.9847363,77.4835742',
#  '12.9837358,77.7516738',
#  '27.4807256,94.9054578',
#  '12.9724159,77.648825',
#  '12.9682211,77.5018354',
#  '12.9582238,77.5341909',
#  '12.9574046,77.5676206',
#  '12.9386844,77.6968463',
#  '12.9353655,77.744042',
#  '12.9292999,77.4870653',
#  '12.95668,78.26914073',
#  '27.1914926,94.9141646',
#  '12.9132655,77.6255704',
#  '12.9082402,77.5478132',
#  '12.9037588,77.5078448',
#  '12.9016662,77.6758605',
#  '12.8975231,77.5999214',
#  '12.8904691,77.6256066',
#  '12.8857143,77.7443073',
#  '12.8725286,77.5834506',
#  '12.8354143,77.6912351',
#  '12.9874656,74.8073202',
#  '12.7301272,77.2800695',
#  '12.8624,74.83577',
#  '28.0454561,95.3308914',
#  '27.354298,95.3340804',
#  '27.489245,95.3571082',
#  '12.5267559,76.8903861',
#  '12.331566,76.609817',
#  '12.3112527,76.647769',
#  '12.18438,75.93355161',
#  '11.4148737,76.7088164',
#  '9.9468524,76.2560285']

# %%
city_name_lst
# Out:
# ['Central Delhi',
#  'South Delhi',
#  'West Delhi',
#  'North East Delhi',
#  'South Delhi',
#  'East Delhi',
#  'South West Delhi',
#  'North East Delhi',
#  'South West Delhi',
#  'West Delhi',
#  'South Delhi',
#  'South West Delhi',
#  'North West Delhi',
#  'South West Delhi',
#  'Ghaziabad',
#  'South West Delhi',
#  'West Delhi',
#  'South West Delhi',
#  'West Delhi',
#  'North West Delhi',
#  'Ghaziabad',
#  'South Delhi',
#  'West Delhi',
#  'North Delhi',
#  'North West Delhi',
#  'West Delhi',
#  'West Delhi',
#  'Ghaziabad',
#  'South West Delhi',
#  'Ghaziabad',
#  'North Delhi',
#  'South Delhi',
#  'Gautam Buddha Nagar',
#  'Gurugram',
#  'North West Delhi',
#  'Gautam Buddha Nagar',
#  'West Delhi',
#  'Ghaziabad',
#  'Gautam Buddha Nagar',
#  'South West Delhi',
#  'Faridabad',
#  'South West Delhi',
#  'Gurugram',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Gurugram',
#  'Ghaziabad',
#  'Ghaziabad',
#  'Gurugram',
#  'Faridabad',
#  'Gautam Buddha Nagar',
#  'Ghaziabad',
#  'Gurugram',
#  'North West Delhi',
#  'Gautam Buddha Nagar',
#  'Gautam Buddha Nagar',
#  'Jhajjar',
#  'Gurgaon',
#  'Gurgaon',
#  'Sonipat',
#  'Ghaziabad',
#  'Gurgaon',
#  'Faridabad',
#  'Bagpat',
#  'Ghaziabad',
#  'Alwar',
#  'Meerut',
#  'Meerut',
#  'Meerut',
#  'Bulandshahr',
#  'Rohtak',
#  'Meerut',
#  'Meerut',
#  'Rewari',
#  'Bulandshahr',
#  'Panipat',
#  'Muzaffarnagar',
#  'Bhiwani',
#  'Muzaffarnagar',
#  'Aligarh',
#  'Aligarh',
#  'Aligarh',
#  'Karnal',
#  'Bijnor',
#  'Mainpuri',
#  'Alwar',
#  'Mathura',
#  'Mathura',
#  'Moradabad',
#  'Moradabad',
#  'Saharanpur',
#  'Hisar',
#  'Saharanpur',
#  'Moradabad',
#  'Bijnor',
#  'Kurukshetra',
#  'Haridwar',
#  'Etah',
#  'Haridwar',
#  'Gurgaon',
#  'Agra',
#  'Agra',
#  'Rampur',
#  'Pauri Garhwal',
#  'Agra',
#  'Udham Singh Nagar',
#  'Ambala',
#  'Dehradun',
#  'Budaun',
#  'Ambala',
#  'Firozabad',
#  'Dehradun',
#  'Dehradun',
#  'Dehradun',
#  'Sirmaur',
#  'Patiala',
#  'Dehradun',
#  'Shikohabad',
#  'Udham Singh Nagar',
#  'Bareilly',
#  'Bareilly',
#  'Bareilly',
#  'Patiala',
#  'Sangrur',
#  'Patiala',
#  'Jaipur',
#  'Jaipur',
#  'Panchkula',
#  'Mainpuri',
#  'Nainital',
#  'Pauri Garhwal',
#  'Fatehgarh Sahib',
#  'Jaipur',
#  'Rupnagar',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Rupnagar',
#  'Panchkula',
#  'Sangrur',
#  'Rewa',
#  'Ludhiana',
#  'Pilibhit',
#  'Solan',
#  'Almora',
#  'Solan',
#  'Rupnagar',
#  'Farrukhabad',
#  'Farrukhabad',
#  'Shimla',
#  'Shimla',
#  'Gwalior',
#  'Bathinda',
#  'Gwalior',
#  'Ludhiana',
#  'Gwalior',
#  'Gwalior',
#  'Gwalior',
#  'Ludhiana',
#  'Ludhiana',
#  'Nawanshahr',
#  'Bilaspur',
#  'Pithoragarh',
#  'Moga',
#  'Kannauj',
#  'Hardoi',
#  'Kapurthala',
#  'Faridkot',
#  'Una',
#  'Auraiya',
#  'Hamirpur',
#  'Muktsar',
#  'Jalandhar',
#  'Firozpur',
#  'Jalandhar',
#  'Mandi',
#  'Ajmer',
#  'Hoshiarpur',
#  'Ganganagar',
#  'Kheri',
#  'Sitapur',
#  'Firozpur',
#  'Jalaun',
#  'Kanpur',
#  'Tarn Taran',
#  'Bikaner',
#  'Kanpur',
#  'Kanpur',
#  'Kanpur',
#  'Kanpur',
#  'Kangra',
#  'Jhansi',
#  'Kanpur',
#  'Kangra',
#  'Ajmer',
#  'Gurdaspur',
#  'Kota',
#  'Amritsar',
#  'Amritsar',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Gurdaspur',
#  'Lucknow',
#  'Lucknow',
#  'Gurdaspur',
#  'Barabanki',
#  'Guna',
#  'Bhilwara',
#  'Bahraich',
#  'Fatehpur',
#  'Chhatarpur',
#  'Raebareli',
#  'Chittorgarh',
#  'Jodhpur',
#  'Jammu',
#  'Jammu',
#  'Jammu',
#  'JAMMU',
#  'Neemuch',
#  'Udhampur',
#  'Faizabad',
#  'Sultanpur',
#  'Mandsaur',
#  'Sagar',
#  'Vidisha',
#  'Udaipur',
#  'Satna',
#  'Damoh',
#  'Prayagraj',
#  'Prayagraj',
#  'Bhopal',
#  'Rajauri',
#  'Bhopal',
#  'Ujjain',
#  'Sehore',
#  'Bhopal',
#  'Rewa',
#  'Katni',
#  'Ujjain',
#  'Ratlam',
#  'Jaunpur',
#  'Gorakhpur',
#  'Gorakhpur',
#  'Gorakhpur',
#  'Srinagar',
#  'Azamgarh',
#  'Azamgarh',
#  'Mirzapur',
#  'Jabalpur',
#  'Indore',
#  'Hoshangabad',
#  'Indore',
#  'Indore',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Varanasi',
#  'Dhar',
#  'Deoria',
#  'Mau',
#  'Ghazipur',
#  'Siwan',
#  'Sidhi',
#  'West Champaran',
#  'Betul',
#  'Chhindwara',
#  'Nalanda',
#  'Siwan',
#  'Ballia',
#  'East Nimar',
#  'Saran',
#  'Bhojpur',
#  'East Nimar',
#  'Aurangabad',
#  'Patna',
#  'Sitamarhi',
#  'Muzaffarpur',
#  'Patna',
#  'Muzaffarpur',
#  'Palamau',
#  'Surguja',
#  'Patna',
#  'Muzaffarpur',
#  'Muzaffarpur',
#  'Nagpur',
#  'Vaishali',
#  'Patna',
#  'Bilaspurcgh',
#  'Bilaspurcgh',
#  'Gaya',
#  'Korba',
#  'Darbhanga',
#  'Nalanda',
#  'Durg',
#  'Rajnandgaon',
#  'Durg',
#  'Nawada',
#  'Raipur',
#  'Raipur',
#  'Raipur',
#  'Begusarai',
#  'Hazaribag',
#  'Lakhisarai',
#  'Mahasamund',
#  'Raigarh',
#  'Saharsa',
#  'Ramgarh',
#  'Ranchi',
#  'Ranchi',
#  'Ranchi',
#  'Valsad',
#  'Jharsuguda',
#  'Giridh',
#  'Bargarh',
#  'Bhagalpur',
#  'Bhagalpur',
#  'Sundergarh',
#  'Sambalpur',
#  'Deoghar',
#  'Bhagalpur',
#  'Dhanbad',
#  'Dhanbad',
#  'Purnia',
#  'Balangir',
#  'Puruliya',
#  'Kishanganj',
#  'Adilabad',
#  'East Singhbhum',
#  'East Singhbhum',
#  'Seraikela-Kharsawan',
#  'Nizamabad',
#  'Karim Nagar',
#  'Bardhaman',
#  'Darjiling',
#  'Darjiling',
#  'North Dinajpur',
#  'East Singhbhum',
#  'Karim Nagar',
#  'Malda',
#  'Jalpaiguri',
#  'Bastar',
#  'Murshidabad',
#  'Pune',
#  'Birbhum',
#  'Medak',
#  'Bidar',
#  'West Midnapore',
#  'Warangal',
#  'Warangal',
#  'South Dinajpur',
#  'South Dinajpur',
#  'Mayurbhanj',
#  'West Midnapore',
#  'Hyderabad',
#  'Cooch Behar',
#  'Hooghly',
#  'Medak',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabd',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Gulbarga',
#  'Hyderabad',
#  'Hyderabad',
#  'Cuttack',
#  'Hyderabad',
#  'Nadia',
#  'Koppal',
#  'Baleswar',
#  'Hyderabad',
#  'Bhadrak',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Cuttack',
#  'K.v.rangareddy',
#  'Hyderabad',
#  'Hyderabad',
#  'Bardhaman',
#  'Khorda',
#  'Khorda',
#  'Khorda',
#  'Howrah',
#  'Hooghly',
#  'North 24 Parganas',
#  'Ganjam',
#  'Nadia',
#  'Kendrapara',
#  'Dhubri',
#  'Rishra',
#  'Hooghly',
#  'Khammam',
#  'North 24 Parganas',
#  'North 24 Parganas',
#  'Nalgonda',
#  'North 24 Parganas',
#  'North 24 Parganas',
#  'North 24 Parganas',
#  'North 24 Parganas',
#  'South 24 Parganas',
#  'Kokrajhar',
#  'Puri',
#  'North 24 Parganas',
#  'Bijapur',
#  'Mahabubnagar',
#  'Srikakulam',
#  'Bongaigaon',
#  'Visakhapatnam',
#  'Goalpara',
#  'Visakhapatnam',
#  'visakhapatnam',
#  'East Godavari',
#  'Barpeta',
#  'Raichur',
#  'Krishna',
#  'Bagalkot',
#  'East Godavari',
#  'Krishna',
#  'Guntur',
#  'Krishna',
#  'West Godavari',
#  'Kurnool',
#  'Nalbari',
#  'Guntur',
#  'Kurnool',
#  'Kamrup',
#  'Krishna',
#  'Kamrup',
#  'Belgaum',
#  'Kurnool',
#  'Prakasam',
#  'Kamrup',
#  'Kamrup',
#  'Kamrup',
#  'Kamrup',
#  'Kamrup',
#  'Kamrup',
#  'Koppal',
#  'Kamrup',
#  'Gadag',
#  'Darrang',
#  'Dharwad',
#  'Bellary',
#  'Dharwad',
#  'Dharwad',
#  'Darrang',
#  'East Khasi Hills',
#  'East Khasi Hills',
#  'Bellary',
#  'Ballari',
#  'West Tripura',
#  'North Goa',
#  'South Goa',
#  'South Goa',
#  'Jaintia Hills',
#  'Ananthapur',
#  'Marigaon',
#  'Cuddapah',
#  'Ananthapur',
#  'Sonitpur',
#  'Sonitpur',
#  'Nellore',
#  'North Tripura',
#  'Karimganj',
#  'Haveri',
#  'Nagaon',
#  'Davangere',
#  'Cuddapah',
#  'Sonitpur',
#  'Cachar',
#  'Chitradurga',
#  'Nellore',
#  'Cachar',
#  'Papum Pare',
#  'Sonitpur',
#  'Cuddapah',
#  'Lower Subansiri',
#  'Karbi Anglong',
#  'Aizawl',
#  'Shivamogga',
#  'Ananthapur',
#  'Shimoga',
#  'Dimapur',
#  'Lakhimpur',
#  'Golaghat',
#  'Chittoor',
#  'Chittoor',
#  'Jorhat',
#  'Chikkaballapur',
#  'Tumkur',
#  'Kohima',
#  'Wokha',
#  'Chickmagalur',
#  'Dhemaji',
#  'Imphal East',
#  'Imphal West',
#  'Udupi',
#  'Sibsagar',
#  'Chittoor',
#  'Kolar',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Thoubal',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Hassan',
#  'Bengaluru',
#  'Bengaluru',
#  'Dibrugarh',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Kolar',
#  'Sibsagar',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bangalore',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Dakshina Kannada',
#  'Ramanagar',
#  'Dakshina Kannada',
#  'East Siang',
#  'Dibrugarh',
#  'Tinsukia',
#  'Mandya',
#  'Mysuru',
#  'Mysore',
#  'Kodagu',
#  'Nilgiris',
#  'Ernakulam']

# %% [markdown]
# # Converting all Lists into a Data frame

# %%
Vishal_store_df=pd.DataFrame(data={'store_name':store_name_lst,'city_name':city_name_lst,'full_address':full_address_lst
                                   ,"Coordinates(Longtude/Latitude)":coordinate_lst,'phone_no':phone_lst,
                                   'store_timing':timing_lst})

# %% [markdown]
# # Webscraped Data

# %%
Vishal_store_df
# Out:
#              store_name         city_name  \
# 0     Vishal Mega Mart      Central Delhi
# 1     Vishal Mega Mart        South Delhi
# 2     Vishal Mega Mart         West Delhi
# 3     Vishal Mega Mart   North East Delhi
# 4     Vishal Mega Mart        South Delhi
# ..                  ...               ...
# 554   Vishal Mega Mart             Mysuru
# 555   Vishal Mega Mart             Mysore
# 556   Vishal Mega Mart             Kodagu
# 557   Vishal Mega Mart           Nilgiris
# 558   Vishal Mega Mart          Ernakulam
#
#                                           full_address  \
# 0     Shop No 10209, 10210, Padam Singh Road, Near ...
# 1     Khirki Extension, Near Sant Nirankari Public ...
# 2     Main Market Rajouri Garden, Block H, H2, Rajo...
# 3     Bholanath Nagar Main Road, Bholanath Nagar, N...
# 4     MCD No 1679, E/1,d/1,2/1679, Khasra No 19 Gal...
# ..                                                 ...
# 554   General Thimmaiah Road, Vijayanagar 1st Stage...
# 555   Shop No 1518, 3, Devaraja Mohalla, Shivarampe...
# 556   Harichandrapura, Thalassery - Mysore Road, SH...
# 557   Plot No 144, Botanical, Garden Road, Garden R...
# 558   Shop No 12/1472, Payyattu Building, Chullicka...
#
#     Coordinates(Longtude/Latitude)        phone_no          store_timing
# 0              28.648012,77.190996  0721 7887 958   10:00 AM to 09:00 PM
# 1            28.5346856,77.2185205  0995 3586 868   10:00 AM to 09:00 PM
# 2            28.6424381,77.1231081  0846 7004 041   10:00 AM to 09:00 PM
# 3             28.6666937,77.286952  0728 9901 351   10:00 AM to 09:00 PM
# 4            28.5341443,77.2598518  0721 7887 898   10:00 AM to 09:00 PM
# ..                             ...             ...                   ...
# 554            12.331566,76.609817              0   09:00 AM to 10:00 PM
# 555           12.3112527,76.647769  0721 7888 413   10:00 AM to 09:00 PM
# 556           12.18438,75.93355161  0845 3698 662   09:00 AM to 10:00 PM
# 557          11.4148737,76.7088164  0721 7887 951   10:00 AM to 09:00 PM
# 558           9.9468524,76.2560285  0721 7888 401   10:00 AM to 09:00 PM
#
# [559 rows x 6 columns]

# %% [markdown]
# ## Saving the dataframe to .csv file

# %%
Vishal_store_df.to_csv('Vishal_store.csv')

# %% [markdown]
# # Thank You
